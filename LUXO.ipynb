# %%
import osmnx as ox # OSMNX is an awnsome package
import pandas as pd

# %%
# Try it !
place = ["Luxembourg" ]
gdf_nodes = gdf_edges = None
for place in place:
    G = ox.graph_from_place(place, retain_all=True, simplify = True, network_type='walk')
    n_, e_ = ox.graph_to_gdfs(G)
    n_["place"] = place
    e_["place"] = place
    if gdf_nodes is None:
        gdf_nodes = n_
        gdf_edges = e_
    else:
        gdf_nodes = pd.concat([gdf_nodes, n_])
        gdf_edges = pd.concat([gdf_edges, e_])
        
# Plot
import matplotlib.pyplot as plt         
from matplotlib.colors import ListedColormap
plt.style.use('dark_background')
colors = {'Luxembourg':'red'}
fig=gdf_edges.plot(column="place", cmap=ListedColormap([colors[k] for k in sorted(colors.keys())]), figsize=(10, 10),
                  alpha=1, linewidth=0.5)

plt.xticks([])
plt.yticks([])
fig.spines['top'].set_visible(False)
fig.spines['right'].set_visible(False)
fig.spines['bottom'].set_visible(False)
fig.spines['left'].set_visible(False)
plt.savefig("3_cities.jpg", dpi=600, format="jpg")
plt.show()

# %%
# We chose the City
place = ["Luxembourg City" ]
gdf_nodes = gdf_edges = None
for place in place:
    G = ox.graph_from_place(place, retain_all=True, simplify = True, network_type='walk')
    n_, e_ = ox.graph_to_gdfs(G)
    n_["place"] = place
    e_["place"] = place
    if gdf_nodes is None:
        gdf_nodes = n_
        gdf_edges = e_
    else:
        gdf_nodes = pd.concat([gdf_nodes, n_])
        gdf_edges = pd.concat([gdf_edges, e_])
        
# Plot it !
import matplotlib.pyplot as plt         
from matplotlib.colors import ListedColormap
plt.style.use('dark_background')
colors = {'Luxembourg':'red'}
fig=gdf_edges.plot(column="place", cmap=ListedColormap([colors[k] for k in sorted(colors.keys())]), figsize=(10, 10),
                  alpha=1, linewidth=0.5)

plt.title("LUXEMBOURG CITY")
plt.xticks([])
plt.yticks([])
fig.spines['top'].set_visible(False)
fig.spines['right'].set_visible(False)
fig.spines['bottom'].set_visible(False)
fig.spines['left'].set_visible(False)
plt.savefig("3_cities.jpg", dpi=600, format="jpg")
plt.show()

# %% [markdown]
# # BONUS
#
# Rather than making 1 notebook per city I'll just add them here.

# %%
# We chose the City
place = ["Brussels" ]
gdf_nodes = gdf_edges = None
for place in place:
    G = ox.graph_from_place(place, retain_all=True, simplify = True, network_type='walk')
    n_, e_ = ox.graph_to_gdfs(G)
    n_["place"] = place
    e_["place"] = place
    if gdf_nodes is None:
        gdf_nodes = n_
        gdf_edges = e_
    else:
        gdf_nodes = pd.concat([gdf_nodes, n_])
        gdf_edges = pd.concat([gdf_edges, e_])
        
# Plot it !
import matplotlib.pyplot as plt         
from matplotlib.colors import ListedColormap
#plt.style.use('dark_background')
colors = {'Brussels':'yellow'}
fig=gdf_edges.plot(column="place", cmap=ListedColormap([colors[k] for k in sorted(colors.keys())]), figsize=(10, 10),
                  alpha=1, linewidth=0.5)

plt.title("BRUSSELS")
plt.xticks([])
plt.yticks([])
fig.spines['top'].set_visible(False)
fig.spines['right'].set_visible(False)
fig.spines['bottom'].set_visible(False)
fig.spines['left'].set_visible(False)
plt.savefig("Brussels.jpg", dpi=600, format="jpg")
plt.show()

# %%
# We chose the City
place = ["Liège" ]
gdf_nodes = gdf_edges = None
for place in place:
    G = ox.graph_from_place(place, retain_all=True, simplify = True, network_type='walk')
    n_, e_ = ox.graph_to_gdfs(G)
    n_["place"] = place
    e_["place"] = place
    if gdf_nodes is None:
        gdf_nodes = n_
        gdf_edges = e_
    else:
        gdf_nodes = pd.concat([gdf_nodes, n_])
        gdf_edges = pd.concat([gdf_edges, e_])
        
# Plot it !
import matplotlib.pyplot as plt         
from matplotlib.colors import ListedColormap
#plt.style.use('dark_background')
colors = {'Liège':'yellow'}
fig=gdf_edges.plot(column="place", cmap=ListedColormap([colors[k] for k in sorted(colors.keys())]), figsize=(10, 10),
                  alpha=1, linewidth=0.5)

plt.title("Liège")
plt.xticks([])
plt.yticks([])
fig.spines['top'].set_visible(False)
fig.spines['right'].set_visible(False)
fig.spines['bottom'].set_visible(False)
fig.spines['left'].set_visible(False)
plt.savefig("FIESTA.jpg", dpi=600, format="jpg")
plt.show()

# %% [markdown]
# # VIVE LA FRANCE !

# %%
# We chose the City
place = ["Paris" ]
gdf_nodes = gdf_edges = None
for place in place:
    G = ox.graph_from_place(place, retain_all=True, simplify = True, network_type='walk')
    n_, e_ = ox.graph_to_gdfs(G)
    n_["place"] = place
    e_["place"] = place
    if gdf_nodes is None:
        gdf_nodes = n_
        gdf_edges = e_
    else:
        gdf_nodes = pd.concat([gdf_nodes, n_])
        gdf_edges = pd.concat([gdf_edges, e_])
        
# Plot it !
import matplotlib.pyplot as plt         
from matplotlib.colors import ListedColormap
#plt.style.use('dark_background')
colors = {'Brussels':'white'}
fig=gdf_edges.plot(column="place", cmap=ListedColormap([colors[k] for k in sorted(colors.keys())]), figsize=(10, 10),
                  alpha=1, linewidth=0.5)

plt.title("PARIS")
plt.xticks([])
plt.yticks([])
fig.spines['top'].set_visible(False)
fig.spines['right'].set_visible(False)
fig.spines['bottom'].set_visible(False)
fig.spines['left'].set_visible(False)
plt.savefig("Paris.jpg", dpi=600, format="jpg")
plt.show()

# %%
# We chose the City
place = ["Marseille" ]
gdf_nodes = gdf_edges = None
for place in place:
    G = ox.graph_from_place(place, retain_all=True, simplify = True, network_type='walk')
    n_, e_ = ox.graph_to_gdfs(G)
    n_["place"] = place
    e_["place"] = place
    if gdf_nodes is None:
        gdf_nodes = n_
        gdf_edges = e_
    else:
        gdf_nodes = pd.concat([gdf_nodes, n_])
        gdf_edges = pd.concat([gdf_edges, e_])
        
# Plot it !
import matplotlib.pyplot as plt         
from matplotlib.colors import ListedColormap
#plt.style.use('dark_background')
colors = {'Brussels':'white'}
fig=gdf_edges.plot(column="place", cmap=ListedColormap([colors[k] for k in sorted(colors.keys())]), figsize=(10, 10),
                  alpha=1, linewidth=0.5)

plt.title("MARSEILLE")
plt.xticks([])
plt.yticks([])
fig.spines['top'].set_visible(False)
fig.spines['right'].set_visible(False)
fig.spines['bottom'].set_visible(False)
fig.spines['left'].set_visible(False)
plt.savefig("Paris.jpg", dpi=600, format="jpg")
plt.show()

# %%
# We chose the City
place = ["Metz" ]
gdf_nodes = gdf_edges = None
for place in place:
    G = ox.graph_from_place(place, retain_all=True, simplify = True, network_type='walk')
    n_, e_ = ox.graph_to_gdfs(G)
    n_["place"] = place
    e_["place"] = place
    if gdf_nodes is None:
        gdf_nodes = n_
        gdf_edges = e_
    else:
        gdf_nodes = pd.concat([gdf_nodes, n_])
        gdf_edges = pd.concat([gdf_edges, e_])
        
# Plot it !
import matplotlib.pyplot as plt         
from matplotlib.colors import ListedColormap
#plt.style.use('dark_background')
colors = {'Metz':'red'}
fig=gdf_edges.plot(column="place", cmap=ListedColormap([colors[k] for k in sorted(colors.keys())]), figsize=(10, 10),
                  alpha=1, linewidth=0.5)

plt.title(" METZ ")
plt.xticks([])
plt.yticks([])
fig.spines['top'].set_visible(False)
fig.spines['right'].set_visible(False)
fig.spines['bottom'].set_visible(False)
fig.spines['left'].set_visible(False)
plt.savefig("Paris.jpg", dpi=600, format="jpg")
plt.show()

# %%
places = ['Los Altos, California, USA',
          {'city':'Los Altos Hills', 'state':'California'},
          'Loyola, California']
G = ox.graph_from_place(places, network_type='drive')
ox.plot_graph(G)
# Out:
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot: >)

# %%
# Try it !
place = ["France" ]
gdf_nodes = gdf_edges = None
for place in place:
    G = ox.graph_from_place(place, retain_all=True, simplify = True, network_type='walk')
    n_, e_ = ox.graph_to_gdfs(G)
    n_["place"] = place
    e_["place"] = place
    if gdf_nodes is None:
        gdf_nodes = n_
        gdf_edges = e_
    else:
        gdf_nodes = pd.concat([gdf_nodes, n_])
        gdf_edges = pd.concat([gdf_edges, e_])
        
# Plot
import matplotlib.pyplot as plt         
from matplotlib.colors import ListedColormap
plt.style.use('dark_background')
colors = {'France':'red'}
fig=gdf_edges.plot(column="place", cmap=ListedColormap([colors[k] for k in sorted(colors.keys())]), figsize=(10, 10),
                  alpha=1, linewidth=0.5)

plt.title(" VIVE LA FRANCE !! ")
plt.xticks([])
plt.yticks([])
fig.spines['top'].set_visible(False)
fig.spines['right'].set_visible(False)
fig.spines['bottom'].set_visible(False)
fig.spines['left'].set_visible(False)
plt.savefig("France.jpg", dpi=600, format="jpg")
plt.show()
